# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
import numpy as np

# %%
a=img.imread("sabito.png")

# %%
plt.imshow(a)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1079.5), np.float64(-0.5))
