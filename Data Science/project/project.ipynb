# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('IPL.csv')
data.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
print("No. of rows : ",data.shape[0],"\nNo. of cols : ",data.shape[1])
# Out:
# No. of rows :  74
# No. of cols :  20

# %%
data.isna().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %% [markdown]
# 1. Which team won the most matches

# %%
teams=data['match_winner'].value_counts()
sns.barplot(x=teams.values,y=teams.index, palette="rainbow")
plt.title("Total Match wins")
# Out:
# C:\Users\BHUMIT SINGH\AppData\Local\Temp\ipykernel_2640\807019143.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=teams.values,y=teams.index, palette="rainbow")
# Text(0.5, 1.0, 'Total Match wins')

# %% [markdown]
# 2. Toss secision trends

# %%
toss=data['toss_decision'].value_counts()
sns.barplot(toss,palette="rainbow")
# sns.countplot(data['toss_decision'])
# Out:
# C:\Users\BHUMIT SINGH\AppData\Local\Temp\ipykernel_2640\3416796699.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(toss,palette="rainbow")
# <Axes: xlabel='toss_decision', ylabel='count'>

# %% [markdown]
# 3. Toss winner vs match winner

# %%
winner=data[data['toss_winner'] == data['match_winner']].value_counts().count()
winner
(winner/74)*100
# Out:
# np.float64(48.64864864864865)

# %% [markdown]
# 4. How do team win ? RUn vs wicket

# %%
win_by=data['won_by'].value_counts()
print("Won by wicket = ", (win_by['Wickets']/data.shape[0])*100)
print("Won by Runs = ", (win_by['Runs']/data.shape[0])*100)
sns.barplot(win_by,palette="rainbow")
# Out:
# Won by wicket =  50.0
# Won by Runs =  50.0
# C:\Users\BHUMIT SINGH\AppData\Local\Temp\ipykernel_2640\3672015106.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(win_by,palette="rainbow")
# <Axes: xlabel='won_by', ylabel='count'>

# %% [markdown]
# ### Player performances

# %% [markdown]
# 1. Most player of the match award

# %%
data.head(1)
awards=data['player_of_the_match'].value_counts().head(10)
awards.idxmax()
sns.barplot(x=awards.values,y=awards.index,palette="magma")
mlt.title("Top 10 player of the match awards")
# Out:
# C:\Users\BHUMIT SINGH\AppData\Local\Temp\ipykernel_2640\2271079227.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=awards.values,y=awards.index,palette="magma")
# Text(0.5, 1.0, 'Top 10 player of the match awards')

# %% [markdown]
# 2. Top 2 scrores

# %%
top=data.groupby("top_scorer")['highscore'].sum().nlargest(2)
sns.barplot(top,palette="magma")
# Out:
# C:\Users\BHUMIT SINGH\AppData\Local\Temp\ipykernel_2640\3773804840.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(top,palette="magma")
# <Axes: xlabel='top_scorer', ylabel='highscore'>

# %% [markdown]
# 3. Best Bowling figure

# %%
best=data['best_bowling_figure'].value_counts().head()
sns.barplot(best,palette="magma")
# Out:
# C:\Users\BHUMIT SINGH\AppData\Local\Temp\ipykernel_2640\475836902.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(best,palette="magma")
# <Axes: xlabel='best_bowling_figure', ylabel='count'>

# %% [markdown]
# 4. Most played venue

# %%
venue=data['venue'].value_counts().head(3)
sns.barplot(x=venue.values,y=venue.index)
venue.idxmax()
# Out:
# 'Wankhede Stadium, Mumbai'

# %% [markdown]
# ### Custom questions

# %% [markdown]
# 1. Who won the highest margin by runs?

# %%
data[data['won_by']=="Runs"].sort_values(by='margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# 2. Player with highest individual score

# %%
data[data['highscore']== data['highscore'].max()][['top_scorer',"highscore"]]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140
