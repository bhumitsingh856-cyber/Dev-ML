# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df = sns.load_dataset("iris")
X=df.drop("species",axis=1)
y=df['species']
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
knn=KNeighborsClassifier()
param_dist = {
    'n_neighbors': np.arange(1, 31, 1),        # 1 to 30
    'weights': ['uniform', 'distance'],
    'p': [1, 2],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}
random_search = RandomizedSearchCV(
    knn,
    param_distributions=param_dist,
    n_iter=20,           # Try 20 random combinations
    cv=5,                # 5-fold cross-validation
    scoring='r2',        # Metric to optimize
    n_jobs=-1,           # Use all CPU cores
    random_state=42,     # Reproducibility
    verbose=1            # Show progress
)

# %%
random_search.fit(X_train, y_train)

# Results
print("=" * 50)
print("RANDOMIZED SEARCH RESULTS")
print("=" * 50)
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best CV R²: {random_search.best_score_:.4f}")
print(f"Test R²: {random_search.score(X_test, y_test):.4f}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\model_selection\_search.py:1234: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
#   warnings.warn(
# ==================================================
# RANDOMIZED SEARCH RESULTS
# ==================================================
# Best Parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': np.int64(27), 'metric': 'manhattan'}
# Best CV R²: nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 9
#       5 print("RANDOMIZED SEARCH RESULTS")
#       6 print("=" * 50)
#       7 print(f"Best Parameters: {random_search.best_params_}")
#       8 print(f"Best CV R²: {random_search.best_score_:.4f}")
# ----> 9 print(f"Test R²: {random_search.score(X_test, y_test):.4f}")
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\model_selection\_search.py:556, in BaseSearchCV.score(self, X, y, **params)
#     553     return scorer(self.best_estimator_, X, y, **score_params)
#     555 # callable
# --> 556 score = self.scorer_(self.best_estimator_, X, y, **score_params)
#     557 if self.multimetric_:
#     558     score = score[self.refit]
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:80, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      78 extra_args = len(args) - len(all_args)
#      79 if extra_args <= 0:
# ---> 80     return f(*args, **kwargs)
#      82 # extra_args > 0
#      83 args_msg = [
#      84     f"{name}={arg}"
#      85     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      86 ]
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\metrics\_scorer.py:322, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     319 if sample_weight is not None:
#     320     _kwargs["sample_weight"] = sample_weight
# --> 322 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\metrics\_scorer.py:463, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     455 y_pred = method_caller(
#     456     estimator,
#     457     _get_response_method_name(response_method),
#     458     X,
#     459     pos_label=pos_label,
#     460 )
#     462 scoring_kwargs = {**self._kwargs, **kwargs}
# --> 463 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\metrics\_regression.py:1288, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#    1284 xp, _, device_ = get_namespace_and_device(y_pred)
#    1285 y_true, sample_weight = move_to(y_true, sample_weight, xp=xp, device=device_)
#    1287 _, y_true, y_pred, sample_weight, multioutput = (
# -> 1288     _check_reg_targets_with_floating_dtype(
#    1289         y_true, y_pred, sample_weight, multioutput, xp=xp
#    1290     )
#    1291 )
#    1293 if _num_samples(y_pred) < 2:
#    1294     msg = "R^2 score is not well-defined with less than two samples."
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\metrics\_regression.py:209, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     160 """Ensures y_true, y_pred, and sample_weight correspond to same regression task.
#     161
#     162 Extends `_check_reg_targets` by automatically selecting a suitable floating-point
#    (...)    205     correct keyword.
#     206 """
#     207 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 209 y_type, y_true, y_pred, sample_weight, multioutput = _check_reg_targets(
#     210     y_true, y_pred, sample_weight, multioutput, dtype=dtype_name, xp=xp
#     211 )
#     213 return y_type, y_true, y_pred, sample_weight, multioutput
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\metrics\_regression.py:115, in _check_reg_targets(y_true, y_pred, sample_weight, multioutput, dtype, xp)
#     112 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
#     114 check_consistent_length(y_true, y_pred, sample_weight)
# --> 115 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     116 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     117 if sample_weight is not None:
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:1035, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1033         array = xp.astype(array, dtype, copy=False)
#    1034     else:
# -> 1035         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1036 except ComplexWarning as complex_warning:
#    1037     raise ValueError(
#    1038         "Complex data not supported\n{}\n".format(array)
#    1039     ) from complex_warning
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\sklearn\utils\_array_api.py:976, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     974     array = numpy.array(array, order=order, dtype=dtype)
#     975 else:
# --> 976     array = numpy.asarray(array, order=order, dtype=dtype)
#     978 # At this point array is a NumPy ndarray. We convert it to an array
#     979 # container that is consistent with the input's namespace.
#     980 return xp.asarray(array)
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\pandas\core\series.py:899, in Series.__array__(self, dtype, copy)
#     896 values = self._values
#     897 if copy is None:
#     898     # Note: branch avoids `copy=None` for NumPy 1.x support
# --> 899     arr = np.asarray(values, dtype=dtype)
#     900 else:
#     901     arr = np.array(values, dtype=dtype, copy=copy)
#
# File c:\Users\BHUMIT SINGH\Documents\Machine Learning\venv\Lib\site-packages\pandas\core\arrays\numpy_.py:193, in NumpyExtensionArray.__array__(self, dtype, copy)
#     191     result = np.array(self._ndarray, dtype=dtype, copy=copy)
#     192 else:
# --> 193     result = np.asarray(self._ndarray, dtype=dtype)
#     195 if (
#     196     self._readonly
#     197     and not copy
#     198     and (dtype is None or astype_is_view(self.dtype, dtype))
#     199 ):
#     200     result = result.view()
#
# ValueError: could not convert string to float: 'versicolor'
